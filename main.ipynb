# %%
# Install
# !pip install scikit-learn pandas

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import classification_report
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2026.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
df = pd.read_csv("tweets.csv")
df.head()
# Out:
#                                          tweet     label
# 0    AI is transforming jobs in a positive way  positive
# 1  Automation is going to eliminate many roles  negative
# 2       Not sure how AI will affect employment   neutral
# 3  AI tools are making work faster and smarter  positive
# 4   I'm afraid robots will replace humans soon  negative

# %%
import re

def clean_text(text):
    text = text.lower()
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    return text

df['tweet'] = df['tweet'].apply(clean_text)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df['tweet'], df['label'], test_size=0.2, random_state=42
)

# %%
vectorizer = CountVectorizer()
X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec = vectorizer.transform(X_test)

# %%
nb = MultinomialNB()
nb.fit(X_train_vec, y_train)
nb_pred = nb.predict(X_test_vec)

print("Naive Bayes:\n", classification_report(y_test, nb_pred))
# Out:
# Naive Bayes:
#                precision    recall  f1-score   support
#
#     negative       1.00      0.67      0.80         6
#      neutral       0.67      0.40      0.50         5
#     positive       0.69      1.00      0.82         9
#
#     accuracy                           0.75        20
#    macro avg       0.79      0.69      0.71        20
# weighted avg       0.78      0.75      0.73        20

# %%
lr = LogisticRegression(max_iter=200)
lr.fit(X_train_vec, y_train)
lr_pred = lr.predict(X_test_vec)

print("Logistic Regression:\n", classification_report(y_test, lr_pred))
# Out:
# Logistic Regression:
#                precision    recall  f1-score   support
#
#     negative       1.00      0.33      0.50         6
#      neutral       0.33      0.20      0.25         5
#     positive       0.60      1.00      0.75         9
#
#     accuracy                           0.60        20
#    macro avg       0.64      0.51      0.50        20
# weighted avg       0.65      0.60      0.55        20

# %%
svm = SVC()
svm.fit(X_train_vec, y_train)
svm_pred = svm.predict(X_test_vec)

print("SVM:\n", classification_report(y_test, svm_pred))
# Out:
# SVM:
#                precision    recall  f1-score   support
#
#     negative       1.00      0.33      0.50         6
#      neutral       0.33      0.20      0.25         5
#     positive       0.60      1.00      0.75         9
#
#     accuracy                           0.60        20
#    macro avg       0.64      0.51      0.50        20
# weighted avg       0.65      0.60      0.55        20
